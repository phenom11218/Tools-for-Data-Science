# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Rami Hammoud
# Data Analyst

# %% [markdown]
# *I am interested in data science because the skillsets that I will learn will help both my career path, and the company that I currently work for*

# %% [markdown]
# ### My code will simply perform the calculation of 2+2 and the print it

# %%
print(2+2)

# %% [markdown]
# My favorite things in life are:
# 1. Pizza ~~with pineapple~~
# 2. Poker
# 3. Family and friends
#
# ![alt text](https://pnimg.net/lrep/2003/43/b16c5cccde5.jpg "Logo Title Text 1")
